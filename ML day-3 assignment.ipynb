# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
D=pd.read_csv('diabetes.csv')
D
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 1              1       85             66             29        0  26.6
# 2              8      183             64              0        0  23.3
# 3              1       89             66             23       94  28.1
# 4              0      137             40             35      168  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# ...

# %%
D.shape
# Out:
# (768, 9)

# %%
N=D.rename(columns={'Pregnancies':'Preg', 'BloodPressure':'BP', 'SkinThickness':'ST', 'DiabetesPedigreeFunction':'DPF', })
N
# Out:
#      Preg  Glucose  BP  ST  Insulin   BMI    DPF  Age  Outcome
# 0       6      148  72  35        0  33.6  0.627   50        1
# 1       1       85  66  29        0  26.6  0.351   31        0
# 2       8      183  64   0        0  23.3  0.672   32        1
# 3       1       89  66  23       94  28.1  0.167   21        0
# 4       0      137  40  35      168  43.1  2.288   33        1
# ..    ...      ...  ..  ..      ...   ...    ...  ...      ...
# 763    10      101  76  48      180  32.9  0.171   63        0
# 764     2      122  70  27        0  36.8  0.340   27        0
# 765     5      121  72  23      112  26.2  0.245   30        0
# 766     1      126  60   0        0  30.1  0.349   47        1
# 767     1       93  70  31        0  30.4  0.315   23        0
#
# [768 rows x 9 columns]

# %%
N.head(10)
# Out:
#    Preg  Glucose  BP  ST  Insulin   BMI    DPF  Age  Outcome
# 0     6      148  72  35        0  33.6  0.627   50        1
# 1     1       85  66  29        0  26.6  0.351   31        0
# 2     8      183  64   0        0  23.3  0.672   32        1
# 3     1       89  66  23       94  28.1  0.167   21        0
# 4     0      137  40  35      168  43.1  2.288   33        1
# 5     5      116  74   0        0  25.6  0.201   30        0
# 6     3       78  50  32       88  31.0  0.248   26        1
# 7    10      115   0   0        0  35.3  0.134   29        0
# 8     2      197  70  45      543  30.5  0.158   53        1
# 9     8      125  96   0        0   0.0  0.232   54        1

# %%
sns.scatterplot(x=N['Preg'], y=N['BP'], hue=N['Age'], size=N['Outcome'])
plt.show()

# %%
sns.pairplot(N, hue='Age', hue_order='BP')
plt.show()

# %%
plt.hist(N['Preg'], bottom=0.5, rwidth=0.5, histtype='stepfilled', bins=10, color='green')
plt.show()

# %%
sns.boxplot(N['Preg'], color='orange', linewidth=2, hue=2)
plt.show()
