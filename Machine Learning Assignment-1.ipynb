# %%
import numpy as np

# %%
array=np.random.randint(10,50, (6,5))
array
# Out:
# array([[27, 15, 17, 10, 34],
#        [31, 49, 17, 31, 15],
#        [25, 17, 31, 38, 25],
#        [33, 33, 26, 43, 16],
#        [13, 48, 48, 11, 11],
#        [17, 13, 25, 39, 48]])

# %%
array[2:4,2:5]
# Out:
# array([[31, 38, 25],
#        [26, 43, 16]])
